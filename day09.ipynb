# %%
import requests
data = {'name':'liuyu','age':'18'}
response = requests.get('http://httpbin.org/get',params=data)
print(response.text)
# Out:
# {"args":{"age":"18","name":"liuyu"},"headers":{"Accept":"*/*","Accept-Encoding":"gzip, deflate","Connection":"close","Host":"httpbin.org","User-Agent":"python-requests/2.18.4"},"origin":"123.178.52.215","url":"http://httpbin.org/get?name=liuyu&age=18"}

# %%
import requests
response=requests.get()

# %% [markdown]
# 文本写入

# %%
liuyu = 'hahahahahahahahahah'
file = '/Users/liuyu/Desktop/text.text'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a1c54ef13e01> in <module>()
#       1 liuyu = 'hahahahahahahahahah'
#       2 file = '/Users/liuyu/Desktop/text.text'
# ----> 3 with open(file,'w',encoding='gbk')as f:
#       4     f.write(liuyu)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/liuyu/Desktop/text.text'

# %%
liuyu = 'hahahahahahahahahah'
file = '/D:\18企业实训/text.text'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-16d9b02197e0> in <module>()
#       1 liuyu = 'hahahahahahahahahah'
#       2 file = '/D:\18企业实训/text.text'
# ----> 3 with open(file,'w',encoding='utf-8')as f:
#       4     f.write(liuyu)
#
# OSError: [Errno 22] Invalid argument: '/D:\x018企业实训/text.text'

# %%
liuyu = 'hahahahahahahahahah'
file = '/D:\18企业实训/text.text'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-39466f4306de> in <module>()
#       1 liuyu = 'hahahahahahahahahah'
#       2 file = '/D:\18企业实训/text.text'
# ----> 3 with open(file,'w',encoding='gbk')as f:
#       4     f.write(liuyu)
#
# OSError: [Errno 22] Invalid argument: '/D:\x018企业实训/text.text'

# %%
liuyu = 'hahahahahahahahahah'
file = 'C:\Users\刘钰\Desktop\text.text'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
#   File "<ipython-input-7-c6c242ca42ca>", line 2
#     file = 'C:\Users\刘钰\Desktop\text.text'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
liuyu = 'hahahahahahahahahah'
file = 'C:\Users\刘钰\Desktop\text.text'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
#   File "<ipython-input-8-c6c242ca42ca>", line 2
#     file = 'C:\Users\刘钰\Desktop\text.text'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
liuyu = 'hahahahahahahahahah'
file = 'C:\Users\刘钰\Desktop\test.txt'
with open(file,'w',encoding='gbk')as f:
    f.write(liuyu)
# Out:
#   File "<ipython-input-9-927f1f81aabe>", line 2
#     file = 'C:\Users\刘钰\Desktop\test.txt'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file_path ='D:\day01\kaifangX.txt'
file = 'C:/Users/刘钰/Desktop/test.txt'
a = open(file,'w',encoding='gbk')

with open(file_path,'r',encoding='gbk',errors='ignore') as f:
    for i in range(10000):
        try:
            emile=f.readline().split(',')[9]
            a.write(emile)
        except Exception as e:
                 print('空行')
a.close()
# Out:
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# 空行
# ...
